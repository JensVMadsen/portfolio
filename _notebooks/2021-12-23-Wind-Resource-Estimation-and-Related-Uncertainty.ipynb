# %% [markdown]
# # Wind Resource Estimation and Related Uncertainty
# > An introduction to wind resource estimation using wind measurements and typical uncertainty quantification using IEC 61400-12.
#
# - toc: false
# - badges: true
# - comments: false
# - categories: [AEP, uncertainty, wind resource, wind measurement]

# %% [markdown]
# ## Introduction
# Here goes the introduction..

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.linspace(0, 10)
y = np.sin(x)
plt.plot(x, y)
plt.grid()
plt.show()
